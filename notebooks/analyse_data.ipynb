# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
#go one level up in folders to import the data_generation module
sys.path.append("..")
from data.data_generation import NonTimeSeriesDataGenerator
#from data.data_generation_ts import TimeSeriesDataGenerator

# %%
# Load and preprocess data
# Load the configuration from the YAML file
pickle_path = '../data/_099999_HEADINGS_TO_LENA.pickle'
#generate the data
generator = NonTimeSeriesDataGenerator(pickle_path)
generator.create_synthetic_data()

  
X_train, y_train = generator.X_train, generator.y_train
X_val, y_val = generator.X_val, generator.y_val
X_test, y_test = generator.X_val, generator.y_val

# %%
#Show statics of all the data
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("X_val shape: ", X_val.shape)
print("y_val shape: ", y_val.shape)
print("X_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (80, 5863)
# y_train shape:  (80,)
# X_val shape:  (30, 5863)
# y_val shape:  (30,)
# X_test shape:  (30, 5863)
# y_test shape:  (30,)

# %%
#show distribution of the target variable
sns.histplot(y_train)
plt.title("Distribution of the target variable in the training set")
plt.show()

#show distribution of the target variable
sns.histplot(y_test)
plt.title("Distribution of the target variable in the test set")
plt.show()

# %%
print(X_train.columns)
# Out:
# Index(['CAN_ICD10FULL_C240', 'CAN_ICD10FULL_C474', 'CAN_ICD10FULL_C185',
#        'CAN_ICD10FULL_C312', 'CAN_ICD10FULL_C252', 'CAN_ICD10FULL_C099',
#        'CAN_ICD10FULL_C399', 'CAN_ICD10FULL_C827', 'CAN_ICD10FULL_C250',
#        'CAN_ICD10FULL_C019',
#        ...
#        'Sun2000niva_2st_52', 'Sun2000niva_2st_53', 'Sun2000niva_2st_54',
#        'Sun2000niva_2st_55', 'Sun2000niva_2st_60', 'Sun2000niva_2st_62',
#        'Sun2000niva_2st_64', 'Sun2000niva_2st_99', 'Sun2000niva_2st_nan',
#        'Kon_equals_1'],
#       dtype='object', length=5863)

# %%
#distribution of the features
sns.histplot(X_train)
plt.title("Distribution of the features in the training set")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 #distribution of the features
# ----> 2 sns.histplot(X_train)
#       3 plt.title("Distribution of the features in the training set")
#       4 plt.show()
#
# File ~/Documents/Project_Dermatology/Dermatology/Code/mellanoma/derma_env/lib/python3.12/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
# ...
