# %%
import os
import pickle
import json
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, classification_report
os.chdir('../')
from data.data_loading import Data_loader
from data.output.analysis.analysis_functions import load_model, load_metrics, analyze_model

# %%
# Paths to the saved model and metrics
model_path = '/Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/data/output/model.pkl'
metrics_path = '/Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/data/output/metrics.json'
output_dir = '/Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/data/output/analysis'

# Load model and metrics
model = load_model(model_path)
metrics = load_metrics(metrics_path)

# Print metrics
print("Model Metrics:")
for metric, value in metrics.items():
    print(f"{metric}: {value}")
# Out:
# Model Metrics:
# accuracy: 0.7333333333333333
# f1_score: 0.0
# roc_auc: 0.5

# %%
data_loader = Data_loader(pickle_path='/Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/data/_099999_HEADINGS_TO_LENA.pickle')
_, _, X_val, y_val = data_loader.load_data()

analyze_model(model, X_val, y_val, output_dir)
# Out:
# /Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/new_derma_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/stempfle/Documents/Project_Dermatology/Dermatology/Code/mellanoma/new_derma_env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
